# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\tri46\Downloads\pokemon.csv')

# %% [markdown]
# Imported necessary packages and csv file.

# %%
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %% [markdown]
# Overview of DF

# %%
df.dtypes
# Out:
# abilities             object
# against_bug          float64
# against_dark         float64
# against_dragon       float64
# against_electric     float64
# against_fairy        float64
# against_fight        float64
# against_fire         float64
# against_flying       float64
# against_ghost        float64
# against_grass        float64
# against_ground       float64
# against_ice          float64
# against_normal       float64
# against_poison       float64
# against_psychic      float64
# against_rock         float64
# against_steel        float64
# against_water        float64
# attack                 int64
# base_egg_steps         int64
# base_happiness         int64
# base_total             int64
# capture_rate          object
# classfication         object
# defense                int64
# experience_growth      int64
# height_m             float64
# hp                     int64
# japanese_name         object
# name                  object
# percentage_male      float64
# ...

# %% [markdown]
# Objects that needed to be dummy encoded: (abilities, classification, japanese name, name, type 1, type 2. Capture rate seems like it shouldn't be an object, so I looked futher into this.

# %%
df.capture_rate.values
# Out:
# array(['45', '45', '45', '45', '45', '45', '45', '45', '45', '255', '120',
#        '45', '255', '120', '45', '255', '120', '45', '255', '127', '255',
#        '90', '255', '90', '190', '75', '255', '90', '235', '120', '45',
#        '235', '120', '45', '150', '25', '190', '75', '170', '50', '255',
#        '90', '255', '120', '45', '190', '75', '190', '75', '255', '50',
#        '255', '90', '190', '75', '190', '75', '190', '75', '255', '120',
#        '45', '200', '100', '50', '180', '90', '45', '255', '120', '45',
#        '190', '60', '255', '120', '45', '190', '60', '190', '75', '190',
#        '60', '45', '190', '45', '190', '75', '190', '75', '190', '60',
#        '190', '90', '45', '45', '190', '75', '225', '60', '190', '60',
#        '90', '45', '190', '75', '45', '45', '45', '190', '60', '120',
#        '60', '30', '45', '45', '225', '75', '225', '60', '225', '60',
#        '45', '45', '45', '45', '45', '45', '45', '255', '45', '45', '35',
# ...

# %% [markdown]
# There's one entry with 30 (Meteorite)255 (Core) that's causing the issue, I changed the value to 255.

# %%
df.replace("30 (Meteorite)255 (Core)", "255", inplace = True)
df.capture_rate.astype('float64')
# Out:
# 0       45.0
# 1       45.0
# 2       45.0
# 3       45.0
# 4       45.0
#        ...
# 796     25.0
# 797    255.0
# 798     15.0
# 799      3.0
# 800      3.0
# Name: capture_rate, Length: 801, dtype: float64

# %% [markdown]
# Changed value converted to float

# %%
dft = pd.get_dummies(df, columns = ['abilities'], drop_first = True)
dft
# Out:
#      against_bug  against_dark  against_dragon  against_electric  \
# 0           1.00           1.0             1.0               0.5
# 1           1.00           1.0             1.0               0.5
# 2           1.00           1.0             1.0               0.5
# 3           0.50           1.0             1.0               1.0
# 4           0.50           1.0             1.0               1.0
# ..           ...           ...             ...               ...
# 796         0.25           1.0             0.5               2.0
# 797         1.00           1.0             0.5               0.5
# 798         2.00           0.5             2.0               0.5
# 799         2.00           2.0             1.0               1.0
# 800         0.25           0.5             0.0               1.0
#
#      against_fairy  against_fight  against_fire  against_flying  \
# 0              0.5            0.5           2.0             2.0
# ...

# %% [markdown]
# Tried to see what would happen if I dummy encoded categorical variables. Seems like too many columns to do meaningful ML especially with 6x categorical variables, so we could leave as is and make graphs.

# %%
df.isnull().sum()
# Out:
# abilities              0
# against_bug            0
# against_dark           0
# against_dragon         0
# against_electric       0
# against_fairy          0
# against_fight          0
# against_fire           0
# against_flying         0
# against_ghost          0
# against_grass          0
# against_ground         0
# against_ice            0
# against_normal         0
# against_poison         0
# against_psychic        0
# against_rock           0
# against_steel          0
# against_water          0
# attack                 0
# base_egg_steps         0
# base_happiness         0
# base_total             0
# capture_rate           0
# classfication          0
# defense                0
# experience_growth      0
# height_m              20
# hp                     0
# japanese_name          0
# name                   0
# percentage_male       98
# pokedex_number         0
# sp_attack              0
# sp_defense             0
# speed                  0
# type1                  0
# ...

# %%
df['height_m'].fillna(df['height_m'].mean(), inplace = True)
df['weight_kg'].fillna(df['weight_kg'].mean(), inplace = True)
df['type2'].fillna(value = 'None', inplace = True)
df['percentage_male'].fillna(df['percentage_male'].mean(), inplace = True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# replacing empty values with average for height, weight, and gender. Added none for empty values for type2.

# %% [markdown]
# 0 null values now

# %%
df.to_csv(r'C:\Users\tri46\OneDrive\Documents\cleaned_Pokemon.csv')
